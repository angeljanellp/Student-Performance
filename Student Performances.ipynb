# %% [markdown]
# # Student Performance in highschool students

# %% [markdown]
# #### Goal:
#
# We are trying in improve our educational systems by implementing some new ressources, such as family support centers, more tutoring, mental-health etc. However, we do not know who to give these too. The goal of this analysis is to group these students based on what they are needing.

# %% [markdown]
# #### Data Source:
# Author: Rabie El Kharoua
#
# year: 2024
#
# title:📚 Students Performance Dataset 📚
#
# publisher:Kaggle
#
# url: https://www.kaggle.com/ds/5195702

# %% [markdown]
# ### Columns and Values:
# StudentID: unique values to the student
#
# Age: 15-18 years old
#
# Gender: Male(0)-Female(1)
#
# Ethnicity: Caucasian(0)-African American(1)- Asian(2)-Other(3)
#
# ParentalEducation: None(0)-High School(1)-Some College(2), Bachelor's(3)- Higher(4)
#
# StudyTimeWeekly: Value of study time per week range from 0h-20h
#
# Absences: value range between 0-30 days
#
# Tutoring: No(0)-Yes(1)
#
# ParentalSupport: None(0)-Low(1)-Moderate(2)-High(3)-Very High(4)
#
# Extracurricular	: No(0)-Yes(1)
#
# Sports: No(0)-Yes(1)
#
# Music: No(0)-Yes(1)
#
# Volunteering: No(0)-Yes(1)
#
# GPA: Average grade of students, range between 0.0-4.0
#
# GradeClass:
# 0: 'A' (GPA >= 3.5)
# 1: 'B' (3.0 <= GPA < 3.5)
# 2: 'C' (2.5 <= GPA < 3.0)
# 3: 'D' (2.0 <= GPA < 2.5)
# 4: 'F' (GPA < 2.0)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set_theme()

# %%
df = pd.read_csv('../Downloads/Student_performance_data _.csv')

# %%
df
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0          1001   17       1          0                  2        19.833723
# 1          1002   18       0          0                  1        15.408756
# 2          1003   15       0          2                  3         4.210570
# 3          1004   17       1          0                  3        10.028829
# 4          1005   17       1          0                  2         4.672495
# ...         ...  ...     ...        ...                ...              ...
# 2387       3388   18       1          0                  3        10.680555
# 2388       3389   17       0          0                  1         7.583217
# 2389       3390   16       1          0                  2         6.805500
# 2390       3391   16       1          1                  0        12.416653
# 2391       3392   16       1          0                  2        17.819907
#
# ...

# %% [markdown]
# ## Data Exploration

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2392 entries, 0 to 2391
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   StudentID          2392 non-null   int64
#  1   Age                2392 non-null   int64
#  2   Gender             2392 non-null   int64
#  3   Ethnicity          2392 non-null   int64
#  4   ParentalEducation  2392 non-null   int64
#  5   StudyTimeWeekly    2392 non-null   float64
#  6   Absences           2392 non-null   int64
#  7   Tutoring           2392 non-null   int64
#  8   ParentalSupport    2392 non-null   int64
#  9   Extracurricular    2392 non-null   int64
#  10  Sports             2392 non-null   int64
#  11  Music              2392 non-null   int64
#  12  Volunteering       2392 non-null   int64
#  13  GPA                2392 non-null   float64
#  14  GradeClass         2392 non-null   float64
# dtypes: float64(3), int64(12)
# memory usage: 280.4 KB

# %%
df.describe()
# Out:
#          StudentID          Age       Gender    Ethnicity  ParentalEducation  \
# count  2392.000000  2392.000000  2392.000000  2392.000000        2392.000000
# mean   2196.500000    16.468645     0.510870     0.877508           1.746237
# std     690.655244     1.123798     0.499986     1.028476           1.000411
# min    1001.000000    15.000000     0.000000     0.000000           0.000000
# 25%    1598.750000    15.000000     0.000000     0.000000           1.000000
# 50%    2196.500000    16.000000     1.000000     0.000000           2.000000
# 75%    2794.250000    17.000000     1.000000     2.000000           2.000000
# max    3392.000000    18.000000     1.000000     3.000000           4.000000
#
#        StudyTimeWeekly     Absences     Tutoring  ParentalSupport  \
# count      2392.000000  2392.000000  2392.000000      2392.000000
# mean          9.771992    14.541388     0.301421         2.122074
# std           5.652774     8.467417     0.458971         1.122813
# ...

# %%
#dropping the student ID, because irrelevant as all unique values

df=df.drop('StudentID', axis=1)

# %%
#what is the age group we are looking at?
df['Age'].unique()
# Out:
# array([17, 18, 15, 16], dtype=int64)

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# #### Which Gender has the highest gpa scores?

# %%
gender=df.groupby('Gender')['GPA'].mean().reset_index()
gender
# Out:
#    Gender       GPA
# 0       0  1.918679
# 1       1  1.894225

# %%
sns.barplot(gender,x='Gender', y='GPA', hue='Gender')
# Out:
# <Axes: xlabel='Gender', ylabel='GPA'>

# %% [markdown]
# ### What is the mean absences per age?

# %%
age=df.groupby('Age')

# %%
abscences=age['Absences'].mean().reset_index()
abscences
# Out:
#    Age   Absences
# 0   15  14.550794
# 1   16  14.807757
# 2   17  14.419080
# 3   18  14.383162

# %%
plt.rcParams['figure.figsize'] = [10, 6]
sns.barplot(abscences, x='Age', y='Absences', hue='Age', palette='colorblind')
plt.title('Average Abscences per Age')
plt.show()

# %% [markdown]
# #### what is their usual weekly study time?

# %%
study_time=age['StudyTimeWeekly'].mean().reset_index()
study_time
# Out:
#    Age  StudyTimeWeekly
# 0   15         9.837934
# 1   16         9.852194
# 2   17         9.573588
# 3   18         9.819003

# %%
sns.barplot(study_time, x='Age', y='StudyTimeWeekly', hue='Age')
plt.title('Average Weekly Study Time');

# %% [markdown]
# #### how many students do after-school activities?

# %%
sums=df[['Tutoring','Extracurricular','Sports','Music','Volunteering']].sum().reset_index()
sums
# Out:
#              index    0
# 0         Tutoring  721
# 1  Extracurricular  917
# 2           Sports  726
# 3            Music  471
# 4     Volunteering  376

# %%
sns.barplot(sums, x='index', y=0, hue='index')
plt.title('Number of students doing after school activites')
plt.xlabel('activity')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
# ### Does doing extracurriculum affect their gpa?

# %%
activity=df.groupby(['Tutoring','Extracurricular','Sports','Music','Volunteering'])['GPA'].mean().reset_index()
activity
# Out:
#     Tutoring  Extracurricular  Sports  Music  Volunteering       GPA
# 0          0                0       0      0             0  1.694474
# 1          0                0       0      0             1  1.629169
# 2          0                0       0      1             0  1.813227
# 3          0                0       0      1             1  2.032224
# 4          0                0       1      0             0  1.750131
# 5          0                0       1      0             1  1.917955
# 6          0                0       1      1             0  2.056766
# 7          0                0       1      1             1  1.857934
# 8          0                1       0      0             0  1.903723
# 9          0                1       0      0             1  1.859163
# 10         0                1       0      1             0  1.955920
# 11         0                1       0      1             1  2.274533
# 12         0                1       1      0             0  1.992683
# ...

# %% [markdown]
# ### does parents support affect their GPA

# %%
support=df.groupby(['ParentalSupport'])['GPA'].mean().reset_index()
support
# Out:
#    ParentalSupport       GPA
# 0                0  1.540128
# 1                1  1.755700
# 2                2  1.884246
# 3                3  2.042409
# 4                4  2.191545

# %%
sns.barplot(support, x='ParentalSupport', y='GPA', hue='ParentalSupport')
plt.title('Parental Support VS. GPA')
# Out:
# Text(0.5, 1.0, 'Parental Support VS. GPA')

# %% [markdown]
# #### scatterplot of their Study weekly time and gpa

# %%
sns.scatterplot(x=df.StudyTimeWeekly, y=df.GPA, hue=df.Age)
plt.title('Weekly Study time VS GPA, based on Age');

# %% [markdown]
# #### scatterplot on their gpa based on their abscences

# %%
sns.scatterplot(x=df.Absences, y=df.GPA, hue=df.Age, palette='magma')
plt.title('Absences vs GPA');

# %% [markdown]
# #### heatmap of columns

# %%
corr=df.corr()
corr
# Out:
#                         Age    Gender  Ethnicity  ParentalEducation  \
# Age                1.000000  0.044895  -0.028473           0.025099
# Gender             0.044895  1.000000   0.016010           0.006771
# Ethnicity         -0.028473  0.016010   1.000000           0.033595
# ParentalEducation  0.025099  0.006771   0.033595           1.000000
# StudyTimeWeekly   -0.006800  0.011469   0.007184          -0.011051
# Absences          -0.011511  0.021479  -0.025712           0.036518
# Tutoring          -0.012076 -0.031597  -0.017440          -0.017340
# ParentalSupport    0.033197  0.008065   0.020922          -0.017463
# Extracurricular   -0.025061 -0.005964  -0.008927           0.007479
# Sports            -0.046320 -0.008897  -0.004484           0.002029
# Music             -0.003492  0.007109  -0.014627           0.039439
# Volunteering       0.013074 -0.000200   0.013468           0.011960
# GPA                0.000275 -0.013360   0.027760          -0.035854
# ...

# %%
sns.heatmap(corr, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## Data Preparation

# %%
# no need to encode as they are a numerical columns
df.dtypes
# Out:
# Age                    int64
# Gender                 int64
# Ethnicity              int64
# ParentalEducation      int64
# StudyTimeWeekly      float64
# Absences               int64
# Tutoring               int64
# ParentalSupport        int64
# Extracurricular        int64
# Sports                 int64
# Music                  int64
# Volunteering           int64
# GPA                  float64
# GradeClass           float64
# dtype: object

# %%
# no need to fill NaN since there are no missing values
df.isnull().sum()
# Out:
# Age                  0
# Gender               0
# Ethnicity            0
# ParentalEducation    0
# StudyTimeWeekly      0
# Absences             0
# Tutoring             0
# ParentalSupport      0
# Extracurricular      0
# Sports               0
# Music                0
# Volunteering         0
# GPA                  0
# GradeClass           0
# dtype: int64

# %%
#due to the data being in different ranges, we will scale the data using Standard Scalers

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_scaled=scaler.fit_transform(df)

# %% [markdown]
# ### Model 1: Kmeans Clustering

# %%
#Create multiple models and do an elbow graph to find the best n_cluster value

from sklearn.cluster import KMeans
ssd=[]
for k in range(2,50):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X_scaled)
    ssd.append(kmeans.inertia_)

# %%
plt.plot(range(2,50), ssd, marker='o')
plt.title('best n_cluster Value');
plt.xlabel('N_cluster VALUE')
plt.ylabel('inertia')
plt.grid(True)

# %%
#it looks like here the elbow is between 10-15

# %%
#creating a model with a n_cluster of 12
kmeans = KMeans(n_clusters=12, random_state=56)
kmeans.fit(X_scaled)
# Out:
# KMeans(n_clusters=12, random_state=56)

# %% [markdown]
# ### Model 2: DBSCAN

# %%
#first create multiple models to find the best eps value, while considering the outliers
from sklearn.cluster import DBSCAN
outliers=[]
eps=np.linspace(0.001,5,50)
for ep in eps:
    dbscan=DBSCAN(eps=ep,min_samples=3)
    dbscan.fit(X_scaled) 
    
    labels = dbscan.labels_
    outlier = (len(df[labels == -1])/len(df))*100
    outliers.append(outlier)

# %%
plt.plot(np.linspace(0.001,5,50), outliers, marker="o", )
plt.title('Best Eps Value')
plt.xlabel('EPS VALUE')
plt.ylabel('percent')
plt.grid(True)

# %%
# looking at the values better with a series
pd.Series(data=outliers,index=eps)
# Out:
# 0.001000    100.000000
# 0.103020    100.000000
# 0.205041    100.000000
# 0.307061    100.000000
# 0.409082    100.000000
# 0.511102     99.874582
# 0.613122     99.874582
# 0.715143     99.874582
# 0.817163     99.749164
# 0.919184     99.372910
# 1.021204     97.198997
# 1.123224     93.561873
# 1.225245     89.548495
# 1.327265     83.821070
# 1.429286     73.285953
# 1.531306     64.005017
# 1.633327     55.602007
# 1.735347     45.819398
# 1.837367     38.377926
# 1.939388     32.023411
# 2.041408     27.591973
# 2.143429     22.115385
# 2.245449     18.185619
# 2.347469     14.172241
# 2.449490     10.869565
# 2.551510      8.152174
# 2.653531      5.518395
# 2.755551      4.055184
# 2.857571      2.717391
# 2.959592      1.588629
# 3.061612      0.919732
# 3.163633      0.585284
# 3.265653      0.376254
# 3.367673      0.209030
# 3.469694      0.209030
# 3.571714      0.041806
# 3.673735      0.041806
# 3.775755      0.041806
# 3.877776      0.000000
# 3.979796      0.000000
# ...

# %%
# here we see that the elbow is situated between 2 and 3
# we will be choosing the eps value of 2.70

dbscan=DBSCAN(eps=2.70,min_samples=2)
dbscan.fit(X_scaled)
# Out:
# DBSCAN(eps=2.7, min_samples=2)

# %% [markdown]
# ## Clustering with both models

# %%
#adding cluster labels
df['Kmeans']=kmeans.labels_
df['DBSCAN']=dbscan.labels_

# %%
df
# Out:
#       Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  Absences  \
# 0      17       1          0                  2        19.833723         7
# 1      18       0          0                  1        15.408756         0
# 2      15       0          2                  3         4.210570        26
# 3      17       1          0                  3        10.028829        14
# 4      17       1          0                  2         4.672495        17
# ...   ...     ...        ...                ...              ...       ...
# 2387   18       1          0                  3        10.680555         2
# 2388   17       0          0                  1         7.583217         4
# 2389   16       1          0                  2         6.805500        20
# 2390   16       1          1                  0        12.416653        17
# 2391   16       1          0                  2        17.819907        13
#
# ...

# %% [markdown]
# #### clusters for weekly study time and gpa

# %%
sns.scatterplot(x=df.StudyTimeWeekly, y=df.GPA, hue=df.Kmeans)
plt.title('Weekly Study time VS GPA, based on Age(KMEANS)')
# Out:
# Text(0.5, 1.0, 'Weekly Study time VS GPA, based on Age(KMEANS)')

# %%
sns.scatterplot(df, x="StudyTimeWeekly", y='GPA', hue='DBSCAN', palette='bright')
plt.title('Weekly Study time VS GPA, based on Age (DBSCAN)')
# Out:
# Text(0.5, 1.0, 'Weekly Study time VS GPA, based on Age (DBSCAN)')

# %%
# in both plots, we dont see that many cluster groups, but we do see that many are in group 10(kmeans) OR  group 0(DBSCAN)

# %% [markdown]
# #### Absence vs GPA

# %%
sns.scatterplot(x=df.Absences, y=df.GPA, hue=df.Kmeans, palette='magma')
plt.title('Absences vs GPA(KMEANS)');

# %%
#here, we do see a bit of clustering, with group 10-11 being farther on the right while most of group 2,8 being top left

# %%
sns.scatterplot(x=df.Absences, y=df.GPA, hue=df.DBSCAN, palette='bright')
plt.title('Absences vs GPA (DSCAN)');

# %%
# here we also see a bit of clustering but not so much, when we see that some colors are closers to each other like group 14, that is higher on the graph .

# %% [markdown]
# ### Parental Support

# %%
support_kmeans=df.groupby('Kmeans')['ParentalSupport'].value_counts().reset_index()
support_kmeans
# Out:
#     Kmeans  ParentalSupport  count
# 0        0                2     68
# 1        0                3     54
# 2        0                1     39
# 3        0                4     21
# 4        0                0     12
# 5        1                2     56
# 6        1                3     47
# 7        1                1     39
# 8        1                0     11
# 9        1                4     10
# 10       2                2     70
# 11       2                3     47
# 12       2                1     40
# 13       2                0     26
# 14       2                4     20
# 15       3                1     42
# 16       3                2     41
# 17       3                3     39
# 18       3                0     21
# 19       3                4     10
# 20       4                3     63
# 21       4                2     56
# 22       4                4     26
# 23       4                1     22
# 24       4                0     10
# 25       5                3     62
# ...

# %%
sns.barplot(support_kmeans, hue='ParentalSupport',y='count', x='Kmeans', palette='bright')
plt.title('Parental Support (kmeans)');

# %%
support_DBSCAN=df.groupby('DBSCAN')['ParentalSupport'].value_counts().reset_index()
support_DBSCAN
# Out:
#     DBSCAN  ParentalSupport  count
# 0       -1                3     27
# 1       -1                2     18
# 2       -1                4     17
# 3       -1                0     16
# 4       -1                1     15
# 5        0                2    601
# 6        0                3    576
# 7        0                1    416
# 8        0                4    211
# 9        0                0    171
# 10       1                2    104
# 11       1                3     82
# 12       1                1     54
# 13       1                4     25
# 14       1                0     22
# 15       2                2      3
# 16       2                3      1
# 17       3                3      2
# 18       4                2      3
# 19       4                3      3
# 20       5                3      2
# 21       5                2      1
# 22       6                3      1
# 23       6                4      1
# 24       7                2      1
# 25       7                3      1
# ...

# %%
sns.barplot(support_DBSCAN, x='DBSCAN', y='count', hue=	'ParentalSupport')
plt.title('Parental Support (DBSCAN)');

# %%
# as we can see, the clusters from the kmeans are more equal in data is seperated compared to DBSCAN put most of the cluster into 1 cluser 
#which is cluster 0

# %% [markdown]
# ### Final Model(KMEANS)

# %%
final_model = KMeans(n_clusters=12, random_state=56)
final_model.fit(X_scaled)
# Out:
# KMeans(n_clusters=12, random_state=56)

# %%
#save model
import joblib

joblib.dump(scaler,"final_scaler(kmeans).joblib")
joblib.dump(final_model,"final_model(kmeans).joblib")
# Out:
# ['final_model(kmeans).joblib']

# %% [markdown]
# ### New predictions

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Ethnicity', 'ParentalEducation', 'StudyTimeWeekly',
#        'Absences', 'Tutoring', 'ParentalSupport', 'Extracurricular', 'Sports',
#        'Music', 'Volunteering', 'GPA', 'GradeClass', 'Kmeans', 'DBSCAN'],
#       dtype='object')

# %%
new_df=pd.DataFrame({'Age':[17], 'Gender':[1], 'Ethnicity':[2], 'ParentalEducation': [3], 'StudyTimeWeekly':[10],
       'Absences':[10], 'Tutoring':[1], 'ParentalSupport':[2], 'Extracurricular':[1], 'Sports':[1],
       'Music':[0], 'Volunteering':[0], 'GPA':[3.2], 'GradeClass':[3]})

# %%
#scale new df
new_df_scaled=scaler.transform(new_df)

# %%
final_model.predict(new_df_scaled)
# Out:
# array([4])
